# %%
#

# %%
list_std = []
list_univ = []
with open("data/lubm/lubm_4","r") as f:
    full = f.readlines()
    for i in range(len(full)):
        if "UndergraduateStudent" in full[i]:
            if "memberOf" in full[i]:
#                 print(full[i].split("memberOf")[0], full[i].split("memberOf")[1].split("\n")[0])
#                 print (full[i].split(" ")[0].split("UndergraduateStudent")[1])
                list_std.append(full[i].split("memberOf")[0].strip())
                list_univ.append(full[i].split("memberOf")[1].split("\n")[0])

# %%
print (len(list_std))
with open("data/test_questions_4.txt","w") as f:
    for i in range(len(list_std)):
        for j in [654]:
            if(list_std[i] != list_std[j]):
                f.write(list_std[i] + list_univ[i] + " " + list_std[j] + list_univ[j] + "\n")

                

# 180 missing Department0.University3/UndergraduateStudent210 Department0.University3
# Out:
# 1482

# %%
print (len(list_std))
with open("data/test_questions_4.txt","w") as f:
    for i in range(len(list_std)):
        if "210" in list_std[i] :
            print i, list_std[i]
#             if(list_std[i] != list_std[j]):
#                 f.write(list_std[i] + list_univ[i] + " " + list_std[j] + list_univ[j] + "\n")

                

# 180 missing Department0.University3/UndergraduateStudent210 Department0.University3
# Out:
# 1482
# 219 Department0.University1/UndergraduateStudent210
# 377 Department0.University2/UndergraduateStudent210
# 654 Department0.University3/UndergraduateStudent210
# 1315 Department1.University0/UndergraduateStudent210

# %%
# print (len(list_std))
with open("data/test_univ.txt","w") as f:
    for i in range(len(uni)):
        for j in range(len(uni)):
            if(uni[i] != uni[j]):
                f.write(uni[j] + " " + uni[j].split(".")[1] + uni[i] + " " + uni[i].split(".")[1] + "\n")

                

# 180 missing

# %%
import numpy as np

# %%
uni = np.unique(list_univ)

print(uni)
# Out:
# [' Department0.University1' ' Department0.University2'
#  ' Department0.University3' ' Department1.University0']

# %%
with open("data/test_questions_full.txt","r") as f:
    aa = f.readlines()
    print(aa[:2])
# Out:
# ['UndergraduateStudent169 http://www.Department0.University3.edu UndergraduateStudent210 http://www.Department0.University3.edu\n', 'UndergraduateStudent169 http://www.Department0.University3.edu UndergraduateStudent223 http://www.Department0.University3.edu\n']

# %%
list_ = []
list_department = []
with open("data/lubm/lubm_3","r") as f:
    full = f.readlines()
    for i in range(len(full)):
        if "UndergraduateStudent" in full[i]:
            if "takesCourse" in full[i]:
                print(full[i])
#                 print(full[i].split("takesCourse")[1].split("\n")[0])
#                 print(full[i].split(" ")[0].split("UndergraduateStudent")[1])
#                 list_corse.append(full[i].split("takesCourse")[1].split("\n")[0])
#                 list_department.append(full[i].split("takesCourse")[1].split("\n")[0].split("/")[0])


#                 list_department.append(full[i].split("takesCourse")[1].split("\n")[0])
# Out:
# Department0.University2/UndergraduateStudent190 takesCourse Department0.University2/Course14
#
# Department0.University2/UndergraduateStudent190 takesCourse Department0.University2/Course40
#
# Department0.University2/UndergraduateStudent53 takesCourse Department0.University2/Course30
#
# Department0.University2/UndergraduateStudent53 takesCourse Department0.University2/Course3
#
# Department0.University2/UndergraduateStudent53 takesCourse Department0.University2/Course26
#
# Department0.University2/UndergraduateStudent53 takesCourse Department0.University2/Course18
#
# Department0.University2/UndergraduateStudent365 takesCourse Department0.University2/Course27
#
# Department0.University2/UndergraduateStudent365 takesCourse Department0.University2/Course3
#
# Department0.University2/UndergraduateStudent365 takesCourse Department0.University2/Course22
#
# Department0.University2/UndergraduateStudent365 takesCourse Department0.University2/Course29
#
# ...

# %%
# print (len(list_std))
with open("data/test_course.txt","w") as f:
    for i in range(10):
        for j in range(len(list_corse)):
            if(list_corse[i] != list_corse[j]):
                f.write(list_corse[j] + list_department[j] + list_corse[i] + list_department[i] + "\n")
